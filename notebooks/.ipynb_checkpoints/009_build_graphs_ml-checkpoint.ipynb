# %% [markdown]
# # Building graphs with Metric Learning
#
# This notebook shows how to build graphs using a metric learning strategy. For this, every hit is independently projected to a latent space using a fully connected neural network. The network is trained to put hits from the same particle close to each other and hits from different particles far from each other. An initial graph can then be constructed by connecting hits that are close in this space.
# This strategy has been adapted by ExaTrkx, see for example [section 5.2 here.](https://link.springer.com/10.1140/epjc/s10052-021-09675-8)
#
# This notebook also serves as an introduction to the new pytorch lightning-based framework.

# %%
from functools import partial
from pathlib import Path

import torch

from gnn_tracking.training.ml import MLModule
from gnn_tracking.models.graph_construction import GraphConstructionFCNN
from gnn_tracking.metrics.losses.metric_learning import GraphConstructionHingeEmbeddingLoss
from pytorch_lightning import Trainer
from gnn_tracking.utils.loading import TrackingDataModule
from gnn_tracking.training.callbacks import PrintValidationMetrics
from gnn_tracking.utils.versioning import assert_version_geq

from torch_geometric.data import Data
from torch import nn
from pytorch_lightning.core.mixins.hparams_mixin import HyperparametersMixin

assert_version_geq("23.12.0")

# %% [markdown]
# ## Step 1: Configuring the data

# %% [markdown]
# The configuration for train/val/test data and its dataloader is held in the `TrackingDataModule` (subclass of `LightningDataModule`).

# %%
# data_dir = Path.cwd().resolve().parent.parent / "test-data" / "data" / "point_clouds" / "v8"
data_dir = Path("/scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/point_clouds_v8/part_1")
assert data_dir.is_dir()

# %%
dm = TrackingDataModule(
    train=dict(
        dirs=[data_dir],
        stop=1,
    ),
    val=dict(
        dirs=[data_dir],
        start=1,
        stop=2,
    ),
    identifier="point_clouds_v8"
    # could also configure a 'test' set here
)

# %% [markdown]
# Other keys allow to configure the loaders (batch size, number of workers, etc.). See the docstring of `TrackingDataModule` for details.

# %% [markdown]
# ### Details (for understanding)

# %% [markdown]
# Note that all of the following will be done implicitly by the `Trainer` and you won't have to worry about it. But if you want to inspect the data, you can do so.
#
# When calling the `setup` method, the `LightningDataModule` initializes instances of `TrackingDataset` (`torch_geometric.Dataset`) for each of these. We can get the corresponding dataloaders by calling `dm.train_dataloader()` and analog for validation and test.
#
# Example:

# %%
# This is called by the Trainer automatically and sets up the datasets
dm.setup(stage="fit")  # 'fit' combines 'train' and 'val'
# Now the datasets are available:
dm.datasets
# Out:
# [04:18:45] INFO: DataLoader will load 1 graphs (out of 900 available).
# [04:18:45] DEBUG: First graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/point_clouds_v8/part_1/data21000_s0.pt, last graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/point_clouds_v8/part_1/data21000_s0.pt
# [04:18:45] INFO: DataLoader will load 1 graphs (out of 900 available).
# [04:18:45] DEBUG: First graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/point_clouds_v8/part_1/data21001_s0.pt, last graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/point_clouds_v8/part_1/data21001_s0.pt
# {'train': TrackingDataset(), 'val': TrackingDataset()}

# %% [markdown]
# For example, we can inspect the first element of the training dataset:

# %%
data = dm.datasets["train"][0]

# %% [markdown]
# To get the corresponding dataloaders, use one of the methods (but again, you probalby won't need to):

# %%
dm.train_dataloader(), dm.val_dataloader()
# Out:
# (<torch_geometric.loader.dataloader.DataLoader at 0x14d535b18610>,
#  <torch_geometric.loader.dataloader.DataLoader at 0x14d535f84b90>)

# %% [markdown]
# ## Step 2: Configuring a model

# %% [markdown]
# We write a normal `torch.nn.Module`. The easiest way is to import one of the modules that we have already written in the `gnn_tracking` librar.

# %%
def ground_truth_classifier(data: Data):
    return (data.particle_id != 0)

class NoiseClassifierModel(nn.Module, HyperparametersMixin):
    def __init__(self):
        super().__init__()

    def forward(self, data: Data):
        return ground_truth_classifier(data)

class WithNoiseClassification(nn.Module, HyperparametersMixin):
    def __init__(self, noise_model,
                in_dim: int,
                out_dim: int,
                depth: int,
                hidden_dim,
                alpha: int = 0.6):
        super().__init__()
        self.noise_model = noise_model
        self.normal_model = GraphConstructionFCNN(in_dim=in_dim, out_dim=out_dim, 
                                                  depth=depth, hidden_dim=hidden_dim)
        self.save_hyperparameters()

    def forward(self, data: Data):
        mask = self.noise_model(data)
        masked_data = data.subgraph(mask)
        out = self.normal_model(masked_data)
        out["hit_mask"] = mask
        return out

# graph_construction_model = GraphConstructionFCNN(in_dim=14, out_dim=8, depth=5, hidden_dim=64)
noise_model = NoiseClassifierModel()
model = WithNoiseClassification(noise_model, 14, 8, 5, 64)

# %%
# noise_model = NoiseClassifierModel()
# noise_model(data)

model(data)
# Out:
# {'H': tensor([[ 0.0346,  0.1199,  0.3469,  ..., -0.1303, -0.2258,  0.2347],
#          [ 0.0344,  0.1177,  0.3440,  ..., -0.1253, -0.2261,  0.2311],
#          [ 0.0334,  0.1160,  0.3411,  ..., -0.1221, -0.2265,  0.2290],
#          ...,
#          [-0.2412,  0.0399,  0.0360,  ...,  0.2827, -0.5113,  0.0805],
#          [-0.2395,  0.0409,  0.0396,  ...,  0.2822, -0.5127,  0.0821],
#          [-0.2401,  0.0402,  0.0382,  ...,  0.2823, -0.5125,  0.0817]],
#         grad_fn=<MulBackward0>),
#  'hit_mask': tensor([ True,  True,  True,  ...,  True, False,  True])}

# %%
graph_construction_model = GraphConstructionFCNN(in_dim=14, out_dim=8, depth=5, hidden_dim=64)

# %% [markdown]
# However, you can also write your own. Here is a very simple one:

# %%
class DemoGraphConstructionModel(nn.Module, HyperparametersMixin):
    def __init__(
        self,
        in_dim: int,
        hidden_dim: int,
        out_dim: int,
        depth: int = 5,
    ):
        super().__init__()
        # This is made available by the HyperparametersMixin
        # all of our hyperparameters from the __init__ arguments
        # are saved to self.hparams (but we don't need this in this
        # example)
        self.save_hyperparameters()
        assert depth > 2
        _layers = [
            nn.Linear(in_dim, hidden_dim),
            nn.ReLU(),
        ]
        for _ in range(depth - 2):
            _layers.append(nn.Linear(hidden_dim, hidden_dim))
            _layers.append(nn.ReLU())
        _layers.append(nn.Linear(hidden_dim, out_dim))
        self._model = nn.Sequential(*_layers)

    def forward(self, data: Data):
        # Our trainer class will expect us to return a dictionary, where
        # the key H has the transformed latent space.
        return {"H": self._model(data.x)}

# %% [markdown]
# Uncomment the next line to use model we just wrote (rather than the default)

# %%
# model = DemoGraphConstructionModel(in_dim=14, out_dim=8, hidden_dim=64)

# %% [markdown]
# If you are familiar with normal pytorch, there was only few differences:
#
# 1. We inherit from `HyperparamsMixin`
# 2. We call `self.save_hyperparameters()`

# %% [markdown]
# ### Details (for understanding)

# %% [markdown]
# We saved all hyperparameters:

# %%
model.hparams
# Out:
# "alpha":       0.6
# "depth":       5
# "hidden_dim":  64
# "in_dim":      14
# "noise_model": NoiseClassifierModel()
# "out_dim":     8

# %% [markdown]
# Note how `depth=5` was saved despite not being specified explicitly (it was recognized as a default parameter).

# %% [markdown]
# As always, you can simply evaluate the `model` on a piece of data:

# %%
out = model(data)

# %%
out["H"][:,1].shape
# Out:
# torch.Size([62352])

# %%
import matplotlib.pyplot as plt

plt.scatter(out["H"][:, 0].detach().numpy(), out["H"][:, 1].detach().numpy(), alpha=0.1, s=10)

# %% [markdown]
# ## Step 3: Configuring loss functions, metrics and the lightning module

# %% [markdown]
# The pytorch model is bundled together with a set of loss functions (just one here), that we backpropagate from in the training step, and a set of metrics. Together, these components make up the `LightningModule` that we pass to the pytorch lightning `Trainer` for training.
#
# If you were familiar with our previous `TCNTrainer` training class, this `MLModule` now fulfills (almost) the exact same role.

# %%
lmodel = MLModule(
    model=model,
    loss_fct=GraphConstructionHingeEmbeddingLoss(
        lw_repulsive=0.5,
        max_num_neighbors=10,
    ),
    optimizer=partial(torch.optim.Adam, lr=1e-4),
)

# %% [markdown]
# ### Details (for understanding)

# %% [markdown]
# Again, all hyperparameters are accessible (even the ones that weren't explicitly specified but only set by default):

# %%
lmodel.hparams
# Out:
# "gc_scanner": None
# "loss_fct":   {'class_path': 'gnn_tracking.metrics.losses.metric_learning.GraphConstructionHingeEmbeddingLoss', 'init_args': {'lw_repulsive': 0.5, 'r_emb': 1.0, 'max_num_neighbors': 10, 'pt_thld': 0.9, 'max_eta': 4.0, 'p_attr': 1.0, 'p_rep': 1.0}}
# "model":      {'class_path': '__main__.WithNoiseClassification', 'init_args': {'noise_model': NoiseClassifierModel(), 'in_dim': 14, 'out_dim': 8, 'depth': 5, 'hidden_dim': 64, 'alpha': 0.6}}
# "preproc":    None

# %% [markdown]
# As you can see, any _objects_ that were passed to the model are also saved to the hyperparameters in a way that we can bring them back.

# %% [markdown]
# The loss function takes output from the model and the data and returns two separate losses:

# %%
data
# Out:
# Data(x=[66114, 14], edge_index=[2, 229066], y=[0], layer=[66114], particle_id=[66114], pt=[66114], reconstructable=[66114], sector=[66114], eta=[66114], n_hits=[66114], n_layers_hit=[66114])

# %%
loss_fct = GraphConstructionHingeEmbeddingLoss()
loss_fct(
    x=out["H"],
    particle_id=data.particle_id,
    batch=data.batch,
    edge_index=data.edge_index,
    pt=data.pt,
    eta=data.eta,
    reconstructable=data.reconstructable,
    true_edge_index=data.edge_index,
    max_num_neighbors=2,
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[42], line 2
#       1 loss_fct = GraphConstructionHingeEmbeddingLoss()
# ----> 2 loss_fct(
#       3     x=out["H"],
#       4     particle_id=data.particle_id,
#       5     batch=data.batch,
#       6     edge_index=data.edge_index,
#       7     pt=data.pt,
#       8     eta=data.eta,
#       9     reconstructable=data.reconstructable,
#      10     true_edge_index=data.edge_index,
#      11     max_num_neighbors=2,
#      12 )
#
# File /scratch/gpfs/aj2239/micromamba/envs/gnn/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /scratch/gpfs/aj2239/micromamba/envs/gnn/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/gnn_tracking/src/gnn_tracking/metrics/losses/metric_learning.py:126, in GraphConstructionHingeEmbeddingLoss.forward(self, x, particle_id, batch, true_edge_index, pt, eta, reconstructable, **kwargs)
#     118 n_hits_oi = mask.sum()
#     119 att_edges, rep_edges = self._get_edges(
#     120     x=x,
#     121     batch=batch,
#    (...)
#     124     particle_id=particle_id,
#     125 )
# --> 126 attr, rep = _hinge_loss_components(
#     127     x=x,
#     128     att_edges=att_edges,
#     129     rep_edges=rep_edges,
#     130     r_emb_hinge=self.hparams.r_emb,
#     131     p_attr=self.hparams.p_attr,
#     132     p_rep=self.hparams.p_rep,
#     133     n_hits_oi=n_hits_oi,
#     134 )
#     135 losses = {
#     136     "attractive": attr,
#     137     "repulsive": rep,
#     138 }
#     139 weights: dict[str, float] = {
#     140     "attractive": 1.0,
#     141     "repulsive": self.hparams.lw_repulsive,
#     142 }
#
# RuntimeError: The following operation failed in the TorchScript interpreter.
# Traceback of TorchScript (most recent call last):
#   File "/home/aj2239/gnn_tracking/src/gnn_tracking/metrics/losses/metric_learning.py", line 26, in _hinge_loss_components
#     eps = 1e-9
#
#     dists_att = norm(x[att_edges[0]] - x[att_edges[1]], dim=-1)
#                      ~~~~~~~~~~~~~~~ <--- HERE
#     norm_att = att_edges.shape[1] + eps
#     v_att = torch.sum(torch.pow(dists_att, p_attr)) / norm_att
# RuntimeError: index 63617 is out of bounds for dimension 0 with size 62352

# %% [markdown]
# Both parts of the loss functions are combined with the loss weight we have configured above (weight of 1 for attractive, weight of 0.5 for repulsive). All of this is done in `MLModule.get_losses` (returning the total loss and a dictionary of the individual losses):

# %%
lmodel.get_losses(out, data)
# Out:
# (tensor(4.8017, grad_fn=<AddBackward0>),
#  {'attractive': tensor(0.0208, grad_fn=<DivBackward1>),
#   'repulsive': tensor(9.5617, grad_fn=<DivBackward1>),
#   'attractive_weighted': 0.020849432796239853,
#   'repulsive_weighted': 4.780872821807861,
#   'n_hits_oi': 10506.0,
#   'n_edges_att': 37848,
#   'n_edges_rep': 100818,
#   'total': 4.801722049713135})

# %% [markdown]
# ## Step 4: Training

# %%
trainer = Trainer(
    max_epochs=1000,
    accelerator="gpu",
    log_every_n_steps=1,
    callbacks=[PrintValidationMetrics()],
)
trainer.fit(model=lmodel, datamodule=dm)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [08:59:31] INFO: DataLoader will load 1 graphs (out of 900 available).
# [08:59:31] DEBUG: First graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/point_clouds_v8/part_1/data21000_s0.pt, last graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/point_clouds_v8/part_1/data21000_s0.pt
# [08:59:31] INFO: DataLoader will load 1 graphs (out of 900 available).
# [08:59:31] DEBUG: First graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/point_clouds_v8/part_1/data21001_s0.pt, last graph is /scratch/gpfs/IOJALVO/gnn-tracking/object_condensation/point_clouds_v8/part_1/data21001_s0.pt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [MIG-74d68ce8-f74a-5408-a325-06b493f31c14]
#
#   | Name     | Type                                | Params
# -----------------------------------------------------------------
# 0 | model    | GraphConstructionFCNN               | 17.8 K
# 1 | loss_fct | GraphConstructionHingeEmbeddingLoss | 0
# -----------------------------------------------------------------
# 17.8 K    Trainable params
# 0         Non-trainable params
# 17.8 K    Total params
# 0.071     Total estimated model params size (MB)
# SLURM auto-requeueing enabled. Setting signal handlers.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                 Validation epoch=0
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.56648 │   nan │
# │ attractive_train          │     2.53843 │   nan │
# │ attractive_weighted       │     2.56648 │   nan │
# │ attractive_weighted_train │     2.53843 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88560.00000 │   nan │
# │ n_edges_rep_train         │ 86610.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.07935 │   nan │
# │ repulsive_train           │     2.01068 │   nan │
# │ repulsive_weighted        │     1.03968 │   nan │
# │ repulsive_weighted_train  │     1.00534 │   nan │
# │ total                     │     3.60616 │   nan │
# │ total_train               │     3.54377 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                   Validation epoch=1
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Metric                    ┃       Value ┃    Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━┩
# │ attractive                │     2.56720 │  0.00047 │
# │ attractive_train          │     2.53950 │      nan │
# │ attractive_weighted       │     2.56720 │  0.00047 │
# │ attractive_weighted_train │     2.53950 │      nan │
# │ n_edges_att               │ 37293.00000 │  0.00000 │
# │ n_edges_att_train         │ 37848.00000 │      nan │
# │ n_edges_rep               │ 88570.00000 │ 20.00000 │
# │ n_edges_rep_train         │ 86646.00000 │      nan │
# │ n_hits_oi                 │ 10284.00000 │  0.00000 │
# │ n_hits_oi_train           │ 10506.00000 │      nan │
# │ repulsive                 │     2.07945 │  0.00006 │
# │ repulsive_train           │     2.01165 │      nan │
# │ repulsive_weighted        │     1.03972 │  0.00003 │
# │ repulsive_weighted_train  │     1.00583 │      nan │
# │ total                     │     3.60692 │  0.00044 │
# │ total_train               │     3.54533 │      nan │
# └───────────────────────────┴─────────────┴──────────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=2
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.56783 │   nan │
# │ attractive_train          │     2.54011 │   nan │
# │ attractive_weighted       │     2.56783 │   nan │
# │ attractive_weighted_train │     2.54011 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88574.00000 │   nan │
# │ n_edges_rep_train         │ 86608.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.07915 │   nan │
# │ repulsive_train           │     2.01082 │   nan │
# │ repulsive_weighted        │     1.03957 │   nan │
# │ repulsive_weighted_train  │     1.00541 │   nan │
# │ total                     │     3.60741 │   nan │
# │ total_train               │     3.54552 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=3
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.56855 │   nan │
# │ attractive_train          │     2.54064 │   nan │
# │ attractive_weighted       │     2.56855 │   nan │
# │ attractive_weighted_train │     2.54064 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88605.00000 │   nan │
# │ n_edges_rep_train         │ 86593.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08003 │   nan │
# │ repulsive_train           │     2.01061 │   nan │
# │ repulsive_weighted        │     1.04001 │   nan │
# │ repulsive_weighted_train  │     1.00530 │   nan │
# │ total                     │     3.60857 │   nan │
# │ total_train               │     3.54594 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=4
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.56936 │   nan │
# │ attractive_train          │     2.54134 │   nan │
# │ attractive_weighted       │     2.56936 │   nan │
# │ attractive_weighted_train │     2.54134 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88572.00000 │   nan │
# │ n_edges_rep_train         │ 86605.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08033 │   nan │
# │ repulsive_train           │     2.01072 │   nan │
# │ repulsive_weighted        │     1.04017 │   nan │
# │ repulsive_weighted_train  │     1.00536 │   nan │
# │ total                     │     3.60953 │   nan │
# │ total_train               │     3.54669 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=5
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.57199 │   nan │
# │ attractive_train          │     2.54220 │   nan │
# │ attractive_weighted       │     2.57199 │   nan │
# │ attractive_weighted_train │     2.54220 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88557.00000 │   nan │
# │ n_edges_rep_train         │ 86598.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08144 │   nan │
# │ repulsive_train           │     2.00975 │   nan │
# │ repulsive_weighted        │     1.04072 │   nan │
# │ repulsive_weighted_train  │     1.00487 │   nan │
# │ total                     │     3.61271 │   nan │
# │ total_train               │     3.54707 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=6
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.57407 │   nan │
# │ attractive_train          │     2.54503 │   nan │
# │ attractive_weighted       │     2.57407 │   nan │
# │ attractive_weighted_train │     2.54503 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88525.00000 │   nan │
# │ n_edges_rep_train         │ 86675.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08103 │   nan │
# │ repulsive_train           │     2.01105 │   nan │
# │ repulsive_weighted        │     1.04052 │   nan │
# │ repulsive_weighted_train  │     1.00553 │   nan │
# │ total                     │     3.61459 │   nan │
# │ total_train               │     3.55056 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=7
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.57569 │   nan │
# │ attractive_train          │     2.54699 │   nan │
# │ attractive_weighted       │     2.57569 │   nan │
# │ attractive_weighted_train │     2.54699 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88579.00000 │   nan │
# │ n_edges_rep_train         │ 86691.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08004 │   nan │
# │ repulsive_train           │     2.01199 │   nan │
# │ repulsive_weighted        │     1.04002 │   nan │
# │ repulsive_weighted_train  │     1.00599 │   nan │
# │ total                     │     3.61571 │   nan │
# │ total_train               │     3.55298 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=8
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.57731 │   nan │
# │ attractive_train          │     2.54841 │   nan │
# │ attractive_weighted       │     2.57731 │   nan │
# │ attractive_weighted_train │     2.54841 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88602.00000 │   nan │
# │ n_edges_rep_train         │ 86701.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08077 │   nan │
# │ repulsive_train           │     2.01241 │   nan │
# │ repulsive_weighted        │     1.04038 │   nan │
# │ repulsive_weighted_train  │     1.00620 │   nan │
# │ total                     │     3.61770 │   nan │
# │ total_train               │     3.55461 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=9
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.57948 │   nan │
# │ attractive_train          │     2.54992 │   nan │
# │ attractive_weighted       │     2.57948 │   nan │
# │ attractive_weighted_train │     2.54992 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88551.00000 │   nan │
# │ n_edges_rep_train         │ 86761.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.07912 │   nan │
# │ repulsive_train           │     2.01220 │   nan │
# │ repulsive_weighted        │     1.03956 │   nan │
# │ repulsive_weighted_train  │     1.00610 │   nan │
# │ total                     │     3.61904 │   nan │
# │ total_train               │     3.55602 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=10
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.58208 │   nan │
# │ attractive_train          │     2.55216 │   nan │
# │ attractive_weighted       │     2.58208 │   nan │
# │ attractive_weighted_train │     2.55216 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88513.00000 │   nan │
# │ n_edges_rep_train         │ 86777.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.07997 │   nan │
# │ repulsive_train           │     2.01289 │   nan │
# │ repulsive_weighted        │     1.03999 │   nan │
# │ repulsive_weighted_train  │     1.00644 │   nan │
# │ total                     │     3.62206 │   nan │
# │ total_train               │     3.55860 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=11
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.58474 │   nan │
# │ attractive_train          │     2.55490 │   nan │
# │ attractive_weighted       │     2.58474 │   nan │
# │ attractive_weighted_train │     2.55490 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88536.00000 │   nan │
# │ n_edges_rep_train         │ 86812.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08148 │   nan │
# │ repulsive_train           │     2.01322 │   nan │
# │ repulsive_weighted        │     1.04074 │   nan │
# │ repulsive_weighted_train  │     1.00661 │   nan │
# │ total                     │     3.62548 │   nan │
# │ total_train               │     3.56151 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=12
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.58705 │   nan │
# │ attractive_train          │     2.55763 │   nan │
# │ attractive_weighted       │     2.58705 │   nan │
# │ attractive_weighted_train │     2.55763 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88600.00000 │   nan │
# │ n_edges_rep_train         │ 86789.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08262 │   nan │
# │ repulsive_train           │     2.01440 │   nan │
# │ repulsive_weighted        │     1.04131 │   nan │
# │ repulsive_weighted_train  │     1.00720 │   nan │
# │ total                     │     3.62836 │   nan │
# │ total_train               │     3.56483 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=13
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.58898 │   nan │
# │ attractive_train          │     2.55987 │   nan │
# │ attractive_weighted       │     2.58898 │   nan │
# │ attractive_weighted_train │     2.55987 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88683.00000 │   nan │
# │ n_edges_rep_train         │ 86774.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08282 │   nan │
# │ repulsive_train           │     2.01471 │   nan │
# │ repulsive_weighted        │     1.04141 │   nan │
# │ repulsive_weighted_train  │     1.00735 │   nan │
# │ total                     │     3.63039 │   nan │
# │ total_train               │     3.56722 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=14
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.59101 │   nan │
# │ attractive_train          │     2.56171 │   nan │
# │ attractive_weighted       │     2.59101 │   nan │
# │ attractive_weighted_train │     2.56171 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88659.00000 │   nan │
# │ n_edges_rep_train         │ 86825.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08296 │   nan │
# │ repulsive_train           │     2.01535 │   nan │
# │ repulsive_weighted        │     1.04148 │   nan │
# │ repulsive_weighted_train  │     1.00768 │   nan │
# │ total                     │     3.63249 │   nan │
# │ total_train               │     3.56939 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=15
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.59333 │   nan │
# │ attractive_train          │     2.56373 │   nan │
# │ attractive_weighted       │     2.59333 │   nan │
# │ attractive_weighted_train │     2.56373 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88642.00000 │   nan │
# │ n_edges_rep_train         │ 86855.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08231 │   nan │
# │ repulsive_train           │     2.01677 │   nan │
# │ repulsive_weighted        │     1.04115 │   nan │
# │ repulsive_weighted_train  │     1.00838 │   nan │
# │ total                     │     3.63449 │   nan │
# │ total_train               │     3.57211 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=16
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.59588 │   nan │
# │ attractive_train          │     2.56613 │   nan │
# │ attractive_weighted       │     2.59588 │   nan │
# │ attractive_weighted_train │     2.56613 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88681.00000 │   nan │
# │ n_edges_rep_train         │ 86897.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08334 │   nan │
# │ repulsive_train           │     2.01827 │   nan │
# │ repulsive_weighted        │     1.04167 │   nan │
# │ repulsive_weighted_train  │     1.00914 │   nan │
# │ total                     │     3.63755 │   nan │
# │ total_train               │     3.57527 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=17
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.59838 │   nan │
# │ attractive_train          │     2.56875 │   nan │
# │ attractive_weighted       │     2.59838 │   nan │
# │ attractive_weighted_train │     2.56875 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88675.00000 │   nan │
# │ n_edges_rep_train         │ 86871.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08365 │   nan │
# │ repulsive_train           │     2.01984 │   nan │
# │ repulsive_weighted        │     1.04182 │   nan │
# │ repulsive_weighted_train  │     1.00992 │   nan │
# │ total                     │     3.64020 │   nan │
# │ total_train               │     3.57867 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=18
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.60079 │   nan │
# │ attractive_train          │     2.57130 │   nan │
# │ attractive_weighted       │     2.60079 │   nan │
# │ attractive_weighted_train │     2.57130 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88748.00000 │   nan │
# │ n_edges_rep_train         │ 86880.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08352 │   nan │
# │ repulsive_train           │     2.02034 │   nan │
# │ repulsive_weighted        │     1.04176 │   nan │
# │ repulsive_weighted_train  │     1.01017 │   nan │
# │ total                     │     3.64255 │   nan │
# │ total_train               │     3.58147 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=19
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.60320 │   nan │
# │ attractive_train          │     2.57376 │   nan │
# │ attractive_weighted       │     2.60320 │   nan │
# │ attractive_weighted_train │     2.57376 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88696.00000 │   nan │
# │ n_edges_rep_train         │ 86926.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08513 │   nan │
# │ repulsive_train           │     2.02218 │   nan │
# │ repulsive_weighted        │     1.04256 │   nan │
# │ repulsive_weighted_train  │     1.01109 │   nan │
# │ total                     │     3.64577 │   nan │
# │ total_train               │     3.58485 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=20
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.60571 │   nan │
# │ attractive_train          │     2.57621 │   nan │
# │ attractive_weighted       │     2.60571 │   nan │
# │ attractive_weighted_train │     2.57621 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88686.00000 │   nan │
# │ n_edges_rep_train         │ 86974.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08705 │   nan │
# │ repulsive_train           │     2.02313 │   nan │
# │ repulsive_weighted        │     1.04353 │   nan │
# │ repulsive_weighted_train  │     1.01156 │   nan │
# │ total                     │     3.64923 │   nan │
# │ total_train               │     3.58777 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=21
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.60838 │   nan │
# │ attractive_train          │     2.57876 │   nan │
# │ attractive_weighted       │     2.60838 │   nan │
# │ attractive_weighted_train │     2.57876 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88673.00000 │   nan │
# │ n_edges_rep_train         │ 86999.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08751 │   nan │
# │ repulsive_train           │     2.02369 │   nan │
# │ repulsive_weighted        │     1.04376 │   nan │
# │ repulsive_weighted_train  │     1.01185 │   nan │
# │ total                     │     3.65214 │   nan │
# │ total_train               │     3.59060 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=22
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.61110 │   nan │
# │ attractive_train          │     2.58150 │   nan │
# │ attractive_weighted       │     2.61110 │   nan │
# │ attractive_weighted_train │     2.58150 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88645.00000 │   nan │
# │ n_edges_rep_train         │ 86970.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08768 │   nan │
# │ repulsive_train           │     2.02392 │   nan │
# │ repulsive_weighted        │     1.04384 │   nan │
# │ repulsive_weighted_train  │     1.01196 │   nan │
# │ total                     │     3.65494 │   nan │
# │ total_train               │     3.59346 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=23
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.61359 │   nan │
# │ attractive_train          │     2.58429 │   nan │
# │ attractive_weighted       │     2.61359 │   nan │
# │ attractive_weighted_train │     2.58429 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88527.00000 │   nan │
# │ n_edges_rep_train         │ 86891.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08665 │   nan │
# │ repulsive_train           │     2.02454 │   nan │
# │ repulsive_weighted        │     1.04333 │   nan │
# │ repulsive_weighted_train  │     1.01227 │   nan │
# │ total                     │     3.65692 │   nan │
# │ total_train               │     3.59656 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=24
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.61566 │   nan │
# │ attractive_train          │     2.58685 │   nan │
# │ attractive_weighted       │     2.61566 │   nan │
# │ attractive_weighted_train │     2.58685 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88531.00000 │   nan │
# │ n_edges_rep_train         │ 86889.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08707 │   nan │
# │ repulsive_train           │     2.02491 │   nan │
# │ repulsive_weighted        │     1.04353 │   nan │
# │ repulsive_weighted_train  │     1.01245 │   nan │
# │ total                     │     3.65920 │   nan │
# │ total_train               │     3.59931 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=25
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.61760 │   nan │
# │ attractive_train          │     2.58892 │   nan │
# │ attractive_weighted       │     2.61760 │   nan │
# │ attractive_weighted_train │     2.58892 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88473.00000 │   nan │
# │ n_edges_rep_train         │ 86888.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08569 │   nan │
# │ repulsive_train           │     2.02503 │   nan │
# │ repulsive_weighted        │     1.04285 │   nan │
# │ repulsive_weighted_train  │     1.01251 │   nan │
# │ total                     │     3.66044 │   nan │
# │ total_train               │     3.60144 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=26
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.61960 │   nan │
# │ attractive_train          │     2.59084 │   nan │
# │ attractive_weighted       │     2.61960 │   nan │
# │ attractive_weighted_train │     2.59084 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88491.00000 │   nan │
# │ n_edges_rep_train         │ 86872.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08589 │   nan │
# │ repulsive_train           │     2.02568 │   nan │
# │ repulsive_weighted        │     1.04294 │   nan │
# │ repulsive_weighted_train  │     1.01284 │   nan │
# │ total                     │     3.66255 │   nan │
# │ total_train               │     3.60368 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=27
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.62202 │   nan │
# │ attractive_train          │     2.59283 │   nan │
# │ attractive_weighted       │     2.62202 │   nan │
# │ attractive_weighted_train │     2.59283 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88497.00000 │   nan │
# │ n_edges_rep_train         │ 86897.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08611 │   nan │
# │ repulsive_train           │     2.02614 │   nan │
# │ repulsive_weighted        │     1.04306 │   nan │
# │ repulsive_weighted_train  │     1.01307 │   nan │
# │ total                     │     3.66507 │   nan │
# │ total_train               │     3.60590 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=28
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.62462 │   nan │
# │ attractive_train          │     2.59524 │   nan │
# │ attractive_weighted       │     2.62462 │   nan │
# │ attractive_weighted_train │     2.59524 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88481.00000 │   nan │
# │ n_edges_rep_train         │ 86935.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08444 │   nan │
# │ repulsive_train           │     2.02810 │   nan │
# │ repulsive_weighted        │     1.04222 │   nan │
# │ repulsive_weighted_train  │     1.01405 │   nan │
# │ total                     │     3.66683 │   nan │
# │ total_train               │     3.60929 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                 Validation epoch=29
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.62718 │   nan │
# │ attractive_train          │     2.59776 │   nan │
# │ attractive_weighted       │     2.62718 │   nan │
# │ attractive_weighted_train │     2.59776 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88540.00000 │   nan │
# │ n_edges_rep_train         │ 86980.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.08488 │   nan │
# │ repulsive_train           │     2.02915 │   nan │
# │ repulsive_weighted        │     1.04244 │   nan │
# │ repulsive_weighted_train  │     1.01457 │   nan │
# │ total                     │     3.66962 │   nan │
# │ total_train               │     3.61233 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# ...
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.09711 │   nan │
# │ repulsive_train           │     2.10017 │   nan │
# │ repulsive_weighted        │     1.04855 │   nan │
# │ repulsive_weighted_train  │     1.05009 │   nan │
# │ total                     │     3.99949 │   nan │
# │ total_train               │     3.83314 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                Validation epoch=859
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.95425 │   nan │
# │ attractive_train          │     2.78264 │   nan │
# │ attractive_weighted       │     2.95425 │   nan │
# │ attractive_weighted_train │     2.78264 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88216.00000 │   nan │
# │ n_edges_rep_train         │ 88943.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.09635 │   nan │
# │ repulsive_train           │     2.09992 │   nan │
# │ repulsive_weighted        │     1.04818 │   nan │
# │ repulsive_weighted_train  │     1.04996 │   nan │
# │ total                     │     4.00242 │   nan │
# │ total_train               │     3.83260 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                Validation epoch=860
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.95398 │   nan │
# │ attractive_train          │     2.78543 │   nan │
# │ attractive_weighted       │     2.95398 │   nan │
# │ attractive_weighted_train │     2.78543 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88231.00000 │   nan │
# │ n_edges_rep_train         │ 88873.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.09717 │   nan │
# │ repulsive_train           │     2.09978 │   nan │
# │ repulsive_weighted        │     1.04859 │   nan │
# │ repulsive_weighted_train  │     1.04989 │   nan │
# │ total                     │     4.00257 │   nan │
# │ total_train               │     3.83532 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                Validation epoch=861
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.94963 │   nan │
# │ attractive_train          │     2.78495 │   nan │
# │ attractive_weighted       │     2.94963 │   nan │
# │ attractive_weighted_train │     2.78495 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88227.00000 │   nan │
# │ n_edges_rep_train         │ 88870.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.09598 │   nan │
# │ repulsive_train           │     2.10018 │   nan │
# │ repulsive_weighted        │     1.04799 │   nan │
# │ repulsive_weighted_train  │     1.05009 │   nan │
# │ total                     │     3.99762 │   nan │
# │ total_train               │     3.83504 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                Validation epoch=862
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.94739 │   nan │
# │ attractive_train          │     2.78063 │   nan │
# │ attractive_weighted       │     2.94739 │   nan │
# │ attractive_weighted_train │     2.78063 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88257.00000 │   nan │
# │ n_edges_rep_train         │ 88849.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.09695 │   nan │
# │ repulsive_train           │     2.09892 │   nan │
# │ repulsive_weighted        │     1.04848 │   nan │
# │ repulsive_weighted_train  │     1.04946 │   nan │
# │ total                     │     3.99587 │   nan │
# │ total_train               │     3.83009 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                Validation epoch=863
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.95137 │   nan │
# │ attractive_train          │     2.77838 │   nan │
# │ attractive_weighted       │     2.95137 │   nan │
# │ attractive_weighted_train │     2.77838 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88163.00000 │   nan │
# │ n_edges_rep_train         │ 88855.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.09532 │   nan │
# │ repulsive_train           │     2.09831 │   nan │
# │ repulsive_weighted        │     1.04766 │   nan │
# │ repulsive_weighted_train  │     1.04916 │   nan │
# │ total                     │     3.99903 │   nan │
# │ total_train               │     3.82754 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                Validation epoch=864
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.95090 │   nan │
# │ attractive_train          │     2.78202 │   nan │
# │ attractive_weighted       │     2.95090 │   nan │
# │ attractive_weighted_train │     2.78202 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88194.00000 │   nan │
# │ n_edges_rep_train         │ 88822.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.09596 │   nan │
# │ repulsive_train           │     2.09978 │   nan │
# │ repulsive_weighted        │     1.04798 │   nan │
# │ repulsive_weighted_train  │     1.04989 │   nan │
# │ total                     │     3.99888 │   nan │
# │ total_train               │     3.83191 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                Validation epoch=865
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.94600 │   nan │
# │ attractive_train          │     2.78127 │   nan │
# │ attractive_weighted       │     2.94600 │   nan │
# │ attractive_weighted_train │     2.78127 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88260.00000 │   nan │
# │ n_edges_rep_train         │ 88877.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.09698 │   nan │
# │ repulsive_train           │     2.10021 │   nan │
# │ repulsive_weighted        │     1.04849 │   nan │
# │ repulsive_weighted_train  │     1.05010 │   nan │
# │ total                     │     3.99448 │   nan │
# │ total_train               │     3.83137 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                Validation epoch=866
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.94604 │   nan │
# │ attractive_train          │     2.77625 │   nan │
# │ attractive_weighted       │     2.94604 │   nan │
# │ attractive_weighted_train │     2.77625 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88209.00000 │   nan │
# │ n_edges_rep_train         │ 88930.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.09697 │   nan │
# │ repulsive_train           │     2.10059 │   nan │
# │ repulsive_weighted        │     1.04849 │   nan │
# │ repulsive_weighted_train  │     1.05029 │   nan │
# │ total                     │     3.99452 │   nan │
# │ total_train               │     3.82654 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                Validation epoch=867
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.94740 │   nan │
# │ attractive_train          │     2.77602 │   nan │
# │ attractive_weighted       │     2.94740 │   nan │
# │ attractive_weighted_train │     2.77602 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88200.00000 │   nan │
# │ n_edges_rep_train         │ 88943.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.09741 │   nan │
# │ repulsive_train           │     2.10106 │   nan │
# │ repulsive_weighted        │     1.04870 │   nan │
# │ repulsive_weighted_train  │     1.05053 │   nan │
# │ total                     │     3.99610 │   nan │
# │ total_train               │     3.82655 │   nan │
# └───────────────────────────┴─────────────┴───────┘
# Validation: |          | 0/? [00:00<?, ?it/s]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
#                Validation epoch=868
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Metric                    ┃       Value ┃ Error ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━┩
# │ attractive                │     2.94587 │   nan │
# │ attractive_train          │     2.77701 │   nan │
# │ attractive_weighted       │     2.94587 │   nan │
# │ attractive_weighted_train │     2.77701 │   nan │
# │ n_edges_att               │ 37293.00000 │   nan │
# │ n_edges_att_train         │ 37848.00000 │   nan │
# │ n_edges_rep               │ 88179.00000 │   nan │
# │ n_edges_rep_train         │ 88921.00000 │   nan │
# │ n_hits_oi                 │ 10284.00000 │   nan │
# │ n_hits_oi_train           │ 10506.00000 │   nan │
# │ repulsive                 │     2.09775 │   nan │
# │ repulsive_train           │     2.10122 │   nan │
# │ repulsive_weighted        │     1.04887 │   nan │
# │ repulsive_weighted_train  │     1.05061 │   nan │
# │ total                     │     3.99474 │   nan │
# │ total_train               │     3.82762 │   nan │
# └───────────────────────────┴─────────────┴───────┘

# %% [markdown]
# ### If there are issues with the progress bar
#
# The lightning progress bar can be finnicky when combined with printing the validation results to the command line, especially when running from a Jupyter notebook. Here's a couple of things to try:
#
# * set `enable_progress_bar=False` in the `Trainer` initialization to disable the progress bar
# * use `callbacks=[pytorch_lightning.callbacks.RichProgressBar(leave=True), ...]` in the `Trainer` initialization (this is a prettier progress bar, anyway). I
# * use `callbacks=[gnn_tracking.utils.lightning.SimpleTqdmProgressBar(leave=True), ...]`
# * remove the `PrintValidationMetrics` callback

# %% [markdown]
# ## Restoring a pre-trained model

# %% [markdown]
# Take a look at the `lightning_logs` directory:

# %%
! ls lightning_logs
# Out:
# version_0  version_1  version_2

# %% [markdown]
# Take the latest version number in the following

# %%
! ls lightning_logs/version_2/checkpoints
# Out:
# 'epoch=0-step=1.ckpt'

# %% [markdown]
# Navigate to one of the versions and take a look at the `hparams.yaml` file. It should contain exactly the hyperparameters from the run.

# %%
! cat lightning_logs/version_2/hparams.yaml
# Out:
# model:
#   class_path: gnn_tracking.models.graph_construction.GraphConstructionFCNN
#   init_args:
#     in_dim: 14
#     hidden_dim: 64
#     out_dim: 8
#     depth: 5
#     alpha: 0.6
# preproc: null
# loss_fct:
#   class_path: gnn_tracking.metrics.losses.metric_learning.GraphConstructionHingeEmbeddingLoss
#   init_args:
#     lw_repulsive: 0.5
#     r_emb: 1.0
#     max_num_neighbors: 10
#     pt_thld: 0.9
#     max_eta: 4.0
#     p_attr: 1.0
#     p_rep: 1.0
# gc_scanner: null

# %% [markdown]
# Similarly, you can check out the `config.yaml` file for additional config values affecting the `Trainer` and other elements of the training process.

# %% [markdown]
# We can bring back the trained model by loading one of the checkpoints:

# %%
restored_model = MLModule.load_from_checkpoint(
    "lightning_logs/version_2/checkpoints/epoch=0-step=1.ckpt"
)
# Out:
# [15:03:04] DEBUG: Getting class GraphConstructionFCNN from module gnn_tracking.models.graph_construction
# [15:03:04] DEBUG: Getting class GraphConstructionHingeEmbeddingLoss from module gnn_tracking.metrics.losses.metric_learning

# %% [markdown]
# Note how we didn't have to specify any the hyperparameters again.
#
# However, we can easily change some of them by adding them as additional keyword arguments.

# %%
restored_model_modified = MLModule.load_from_checkpoint(
    "lightning_logs/version_2/checkpoints/epoch=0-step=1.ckpt",
    loss_fct=GraphConstructionHingeEmbeddingLoss(lw_repulsive=0.1, max_num_neighbors=5),
)
# Out:
# [15:03:23] DEBUG: Getting class GraphConstructionFCNN from module gnn_tracking.models.graph_construction

# %% [markdown]
# Note that you cannot modify the model architecture however (but you could in principle change the `beta` parameter of the residual connections).

# %% [markdown]
# ## Running all of this from the command line

# %% [markdown]
# All of the following can be achieved by running the following command:
#
# ```bash
# python3 gnn_tracking/trainers/run.py fit --model configs/model.yml --data configs/data.yml  --trainer.accelerator cpu --trainer.accelerator cpu
# ```
#
# with the data config file
#
# ```yaml
# train:
#   dirs:
#     - /path/to/your/dir
#   stop: 5
# test:
#   dirs:
#     - /path/to/your/dir
#   star: 10
#   stop: 15
# val:
#   dirs:
#     - /path/to/your/dir
#   start: 5
#   stop: 10
# identifier: point_clouds_v8
# ```
#
# and model config file:
#
# ```yaml
# class_path: gnn_tracking.training.ml.MLModule
# init_args:
#   model:
#     class_path: gnn_tracking.models.graph_construction.GraphConstructionFCNN
#     init_args:
#       in_dim: 14
#       out_dim: 8
#       hidden_dim: 512
#       depth: 5
#   loss_fct:
#     class_path: gnn_tracking.metrics.losses.GraphConstructionHingeEmbeddingLoss
#     init_args:
#       lw_repulsive: 0.5
#   optimizer:
#     class_path: torch.optim.Adam
#     init_args:
#       lr: 0.0001
# ```

# %% [markdown]
# To quickly override one of the options, you can simply add them to the command line, e.g., `--model.init_args.loss_fct.init_args.lw_repulsive=0.1` or `--model.model.init_args.depth=6`.

# %% [markdown]
# ## Advanced: Connecting with Weights & Biases
#
# Weights and Biases (wandb.ai) is a great tool to log all of your runs to.
# It's also very easy to set up in principle by adding a callback to the `Trainer`.
#
# However, first you need to create an account (it's free!). If you collaborate with us, you probably want to reach out to us so that we can add you to our project (and can see each other's runs).
#
# Once you have your account, copy your API key into the file `~/.wandb_api_key` on the server from which you run your ML models.
#
# Because we want to later identify our current trial among other trials (and have an easy-to-remember name), let's first create an identifier:

# %%
from gnn_tracking.utils.nomenclature import random_trial_name

# %%
name = random_trial_name()
# Out:
# ─────────────────────────── demonic-logical-platypus ───────────────────────────

# %% [markdown]
# After this, let's set up the logger:

# %%
from pytorch_lightning.loggers import WandbLogger


wandb_logger = WandbLogger(
    project="ml",
    group="first",
    offline=True,  # <-- see notes below
    version=name,
)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING `resume` will be ignored since W&B syncing is set to `offline`. Starting a new run with run id godlike-buzzard-of-wonder.
# Tracking run with wandb version 0.15.4
# W&B syncing is set to <code>`offline`<code> in this directory.  <br/>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.

# %% [markdown]
# We want to keep our checkpoints locally, so let's also initialize the default logger (which would be replaced by `WandbLogger` if we don't add it manually):

# %%
from pytorch_lightning.loggers import TensorBoardLogger


tb_logger = TensorBoardLogger(".", version=name)

# %% [markdown]
# Now we'd have all the places in place, if it weren't for one subtlety: The Princeton compute nodes don't have internet connectivity.
# This is also why we set `offline=True` to the `WandbLogger`. But that's not a problem, because we have internet on the head node `della-gpu`
# (just not on the compute node). So we can simply run `wandb sync /path/to/run/dir` afterwards.
# However, because this is annoying, I wrote a package `wandb-osh` to help with this.
#
# To install it, run:

# %%
! pip3 install wandb-osh
# Out:
# Requirement already satisfied: wandb-osh in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (1.0.4)
# Requirement already satisfied: colorlog in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb-osh) (6.7.0)
# Requirement already satisfied: wandb in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb-osh) (0.15.4)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb->wandb-osh) (8.1.3)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb->wandb-osh) (3.1.31)
# Requirement already satisfied: requests<3,>=2.0.0 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb->wandb-osh) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb->wandb-osh) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb->wandb-osh) (1.21.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb->wandb-osh) (0.4.0)
# Requirement already satisfied: PyYAML in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb->wandb-osh) (6.0)
# Requirement already satisfied: pathtools in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb->wandb-osh) (0.1.2)
# Requirement already satisfied: setproctitle in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb->wandb-osh) (1.3.2)
# Requirement already satisfied: setuptools in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb->wandb-osh) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb->wandb-osh) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from wandb->wandb-osh) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from docker-pycreds>=0.4.0->wandb->wandb-osh) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->wandb-osh) (4.0.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb->wandb-osh) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb->wandb-osh) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb->wandb-osh) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb->wandb-osh) (2023.5.7)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/fuchur/micromamba/envs/gnn/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->wandb-osh) (3.0.5)

# %% [markdown]
# Now let's put everything together:

# %%
from wandb_osh.lightning_hooks import TriggerWandbSyncLightningCallback


trainer = Trainer(
    max_epochs=3,
    accelerator="cpu",
    log_every_n_steps=1,
    callbacks=[
        TriggerWandbSyncLightningCallback(),
        PrintValidationMetrics(),
    ],
    logger=[
        wandb_logger,
        tb_logger,
    ],
)

# %% [markdown]
# To sync your run, simply start the `wandb-osh` command line utility on `della-gpu`.
# For more information on how this works, see [here](https://github.com/klieret/wandb-offline-sync-hook).
